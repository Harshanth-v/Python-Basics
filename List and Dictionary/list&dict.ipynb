# %%
#list programs

# %%
lst = [1,2,3,4,5]
print(len(lst))
# Out:
# 5

# %%
print(len(lst)==0)
# Out:
# False

# %%
lst.append(6)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lst.insert(2,10)
print(lst)
# Out:
# [1, 2, 10, 3, 4, 5, 6]

# %%
lst.remove(10)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(lst.count(2))
# Out:
# 1

# %%
lst.sort()
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lst.reverse()
print(lst)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
print(max(lst))
# Out:
# 6

# %%
print(min(lst))
# Out:
# 1

# %%
print(3 in lst)
# Out:
# True

# %%
lst2=[7,8,9]
print(lst+lst2)
# Out:
# [6, 5, 4, 3, 2, 1, 7, 8, 9]

# %%
lst.clear()
print(lst)
# Out:
# []

# %%
lst=[1,2,3]
copy_lst=lst.copy()
print(copy_lst)
# Out:
# [1, 2, 3]

# %%
print(lst.index(2))
# Out:
# 1

# %%
lst.pop()
print(lst)
# Out:
# [1, 2]

# %%
lst.extend([4,5])
print(lst)
# Out:
# [1, 2, 4, 5]

# %%
lst=[1,2,2,3,3,4]
print(list(set(lst)))
# Out:
# [1, 2, 3, 4]

# %%
print(sum(lst))
# Out:
# 15

# %%
print(sum(lst)/len(lst))
# Out:
# 2.5

# %%
print(lst.index(2))
# Out:
# 1

# %%
print([1,2,3]==[1,2,3])
# Out:
# True

# %%
a,b=[1,2,3],[2,3,4]
print(list(set(a)&set(b)))
# Out:
# [2, 3]

# %%
lst=[10,20,30,40]
print(sorted(set(lst))[-2])
# Out:
# 30

# %%
lst=[1,2,3,4]
print(lst==sorted(lst))
# Out:
# True

# %%
#dictionary programs

# %%
d = {"a": 1, "b": 2}
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
print(d["a"])
# Out:
# 1

# %%
d["c"] = 3
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d["a"] = 10
print(d)
# Out:
# {'a': 10, 'b': 2, 'c': 3}

# %%
d.pop("b")
print(d)
# Out:
# {'a': 10, 'c': 3}

# %%
d.popitem()
print(d)
# Out:
# {'a': 10}

# %%
print(d.get("a"))
# Out:
# 10

# %%
print("a" in d)
# Out:
# True

# %%
print(d.keys())
# Out:
# dict_keys(['a'])

# %%
print(d.values())
# Out:
# dict_values([10])

# %%
print(d.items())
# Out:
# dict_items([('a', 10)])

# %%
copy_d = d.copy()
print(copy_d)
# Out:
# {'a': 10}

# %%
d = dict.fromkeys(["x","y"], 0)
print(d)
# Out:
# {'x': 0, 'y': 0}

# %%
d1, d2 = {"a":1}, {"b":2}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %%
d.clear()
print(d)
# Out:
# {}

# %%
squares = {x: x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
print(len(squares))
# Out:
# 5

# %%
print(max(squares))
# Out:
# 4

# %%
print(min(squares))
# Out:
# 0

# %%
print(sum(squares.values()))
# Out:
# 30

# %%
print(len(squares)==0)
# Out:
# False

# %%
print(dict(sorted(squares.items())))
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
print(dict(sorted(squares.items(), key=lambda x: x[1])))
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
nested = {"person": {"name":"darshan", "age":22}}
print(nested)
# Out:
# {'person': {'name': 'darshan', 'age': 22}}

# %%
print(nested["person"]["name"])
# Out:
# darshan

# %%
#string programs

# %%
s = "bangalore"
print(len(s))
# Out:
# 9

# %%
print(len(s)==0)
# Out:
# False

# %%
print(s.upper())
# Out:
# BANGALORE

# %%
print(s.lower())
# Out:
# bangalore

# %%
print(s.capitalize())
# Out:
# Bangalore

# %%
print(s.title())
# Out:
# Bangalore

# %%
print(s.swapcase())
# Out:
# BANGALORE

# %%
print("123".isdigit())
# Out:
# True

# %%
print("abc".isalpha())
# Out:
# True

# %%
print("abc123".isalnum())
# Out:
# True

# %%
print(s.count("l"))
# Out:
# 1

# %%
print(s.find("e"))
# Out:
# 8

# %%
print(s.replace("b","B"))
# Out:
# Bangalore

# %%
print("  hi  ".strip())
# Out:
# hi

# %%
print("  hi".lstrip())
# Out:
# hi

# %%
print("hi  ".rstrip())
# Out:
# hi

# %%
print(s.startswith("he"))
# Out:
# False

# %%
print(s.endswith("re"))
# Out:
# True

# %%
print(s.split())
# Out:
# ['bangalore']

# %%
print(" ".join(["hi","there"]))
# Out:
# hi there

# %%
print(s.center(20,"-"))
# Out:
# -----bangalore------

# %%
print(s.ljust(20,"-"))
# Out:
# bangalore-----------

# %%
print(s.rjust(15,"-"))
# Out:
# ------bangalore

# %%
print("city centre".istitle())
# Out:
# False

# %%
print("BMW".isupper())
# Out:
# True
